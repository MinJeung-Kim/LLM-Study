# %% [markdown]
# # seq2seq (Sequence-to-Sequence)

# %% [markdown]
# ### Embedding Vector 준비
#
# 1. 영어 glove 임베딩 (사전 학습) 사용 / 6B tokens, 400K vocab, uncased, 100d
# 2. 한국어 임베딩 (초기 훈련)

# %%
# !gdown 1qk-14tgVHPXT5jfRUE4Ua2ji4EXwS022

# %% [markdown]
# ### 학습 데이터 준비
#
# http://www.manythings.org/anki/
#
# eng-kor 짝으로 이루어진 학습 데이터
#
# 1. Encoder 입력 데이터 eng
#     - encoder_input_eng 준비 `I love you`
# 2. Decoder 출력 데이터 kor
#     - 학습용 teacher-forcing 모델
#         - decoder_input_kor `<sos> 난 널 사랑해`
#         - decoder_output_kor `난 널 사랑해 <eos>`
#     - 추론용 모델

# %%
# !gdown 17X1AF5lusy-FP-Zadm-DDpbeKIZ1cWmH -O eng_kor.txt

# %%
eng_inputs = []
kor_inputs = []
kor_targets = []

with open('eng_kor.txt', 'r', encoding='UTF-8') as f:
    for line in f:
        eng, kor, _ = line.split('\t')

        kor_input = '<sos> ' + kor
        kor_target = kor + ' <eos>'

        eng_inputs.append(eng)
        kor_inputs.append(kor_input)
        kor_targets.append(kor_target)

len(eng_inputs), len(kor_inputs), len(kor_targets)
# Out:
# (5890, 5890, 5890)

# %%
print(eng_inputs[2500:2505])
print(kor_inputs[2500:2505])
print(kor_targets[2500:2505])
# Out:
# ['I speak French a little.', 'I take back what I said.', 'I tried to make friends.', 'I use this all the time.', 'I use this all the time.']
# ['<sos> 저는 프랑스어를 조금 합니다.', '<sos> 아까 한 말 취소야.', '<sos> 난 친구를 만드려고 했어.', '<sos> 나는 항상 이걸 쓴다.', '<sos> 매번 이걸 쓴다.']
# ['저는 프랑스어를 조금 합니다. <eos>', '아까 한 말 취소야. <eos>', '난 친구를 만드려고 했어. <eos>', '나는 항상 이걸 쓴다. <eos>', '매번 이걸 쓴다. <eos>']

# %% [markdown]
# ### 토큰화
#
# - 인코더(영어) : 영문 토커나이저
# - 디코더(한글) : 국문 토커나이저

# %%
VOCAB_SIZE = 10000

# %% [markdown]
# ### 영문 토큰화

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

eng_tokenizer = Tokenizer(num_words=VOCAB_SIZE, oov_token='<oov>')
eng_tokenizer.fit_on_texts(eng_inputs)
eng_inputs_seq = eng_tokenizer.texts_to_sequences(eng_inputs)

eng_inputs_seq[2500:2505]
# Out:
# [[2, 130, 38, 8, 268],
#  [2, 111, 150, 27, 2, 82],
#  [2, 300, 4, 213, 202],
#  [2, 206, 12, 54, 6, 60],
#  [2, 206, 12, 54, 6, 60]]

# %%
for seq in eng_inputs_seq[2500:2505]:
    print([eng_tokenizer.index_word[idx] for idx in seq])
# Out:
# ['i', 'speak', 'french', 'a', 'little']
# ['i', 'take', 'back', 'what', 'i', 'said']
# ['i', 'tried', 'to', 'make', 'friends']
# ['i', 'use', 'this', 'all', 'the', 'time']
# ['i', 'use', 'this', 'all', 'the', 'time']

# %%
eng_num_words = min(VOCAB_SIZE, len(eng_tokenizer.word_index))
eng_max_len = max([len(seq) for seq in eng_inputs_seq])

# %% [markdown]
# ### 국문 토큰화

# %%
# 기본값: filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'
kor_tokenizer = Tokenizer(num_words=VOCAB_SIZE, oov_token='<oov>', filters='')
kor_tokenizer.fit_on_texts(kor_inputs + kor_targets) # <sos>, <eos> 포함

kor_inputs_seq = kor_tokenizer.texts_to_sequences(kor_inputs)
kor_targets_seq = kor_tokenizer.texts_to_sequences(kor_targets)

kor_inputs_seq[1000:1001], kor_targets_seq[1000:1001]
# Out:
# ([[2, 81, 1655]], [[81, 1655, 3]])

# %%
kor_tokenizer.index_word
# Out:
# {1: '<oov>',
#  2: '<sos>',
#  3: '<eos>',
#  4: '톰은',
#  5: '나는',
#  6: '톰이',
#  7: '난',
#  8: '있어.',
#  9: '그',
#  10: '내가',
#  11: '수',
#  12: '이',
#  13: '내',
#  14: '그는',
#  15: '있다.',
#  16: '있어?',
#  17: '네가',
#  18: '것',
#  19: '우리는',
#  20: '것을',
#  21: '더',
#  22: '왜',
#  23: '할',
#  24: '너무',
#  25: '너',
#  26: '좀',
#  27: '안',
#  28: '네',
#  29: '정말',
#  30: '거야.',
#  31: '않아.',
#  32: '우리',
#  33: '한',
#  34: '없어.',
#  35: '같아.',
#  36: '그녀는',
#  37: '알고',
#  38: '걸',
#  39: '것이다.',
#  40: '프랑스어를',
#  41: '있는',
#  42: '없다.',
#  43: '줄',
#  44: '한다.',
#  45: '않는다.',
#  46: '이건',
#  47: '우린',
#  48: '잘',
#  49: '가장',
#  50: '해.',
#  51: '너는',
#  52: '톰을',
#  53: '하고',
#  54: '적',
#  55: '집에',
#  56: '사람은',
#  57: '했다.',
#  58: '그걸',
#  59: '아무도',
#  60: '여기',
#  61: '있을',
#  62: '건',
#  63: '날',
#  64: '넌',
#  65: '것은',
#  66: '그렇게',
#  67: '메리가',
#  68: '톰과',
#  69: '했어.',
#  70: '지금',
#  71: '않았다.',
#  72: '톰의',
#  73: '오늘',
#  74: '무슨',
#  75: '얼마나',
#  76: '그게',
#  77: '좋은',
#  78: '것이',
#  79: '아주',
#  80: '그의',
#  81: '나',
#  82: '그것을',
#  83: '하지',
#  84: '그건',
#  85: '어떻게',
#  86: '있었어.',
#  87: '적이',
#  88: '못',
#  89: '우리가',
#  90: '그가',
#  91: '누가',
#  92: '있었다.',
#  93: '거야?',
#  94: '아직도',
#  95: '모두',
#  96: '이게',
#  97: '내일',
#  98: '게',
#  99: '아직',
#  100: '좋아하는',
#  101: '주세요.',
#  102: '이거',
#  103: '다',
#  104: '때',
#  105: '당신은',
#  106: '톰한테',
#  107: '톰에게',
#  108: '그들은',
#  109: '메리는',
#  110: '아니야.',
#  111: '마.',
#  112: '계속',
#  113: '않다.',
#  114: '어떤',
#  115: '하는',
#  116: '널',
#  117: '모든',
#  118: '자기',
#  119: '사람들은',
#  120: '같이',
#  121: '많이',
#  122: '말했다.',
#  123: '그만',
#  124: '않았어.',
#  125: '말을',
#  126: '않을',
#  127: '책을',
#  128: '싶지',
#  129: '많은',
#  130: '대해',
#  131: '싶어.',
#  132: '이것은',
#  133: '어제',
#  134: '몇',
#  135: '전에',
#  136: '거짓말',
#  137: '이걸',
#  138: '다시',
#  139: '법을',
#  140: '사람이',
#  141: '미안해.',
#  142: '저',
#  143: '나를',
#  144: '둘',
#  145: '없었다.',
#  146: '갈',
#  147: '큰',
#  148: '보스턴에',
#  149: '이상',
#  150: '거기',
#  151: '학교에',
#  152: '메리를',
#  153: '가지',
#  154: '너한테',
#  155: '프랑스어',
#  156: '항상',
#  157: '안다.',
#  158: '여기에',
#  159: '뭔가',
#  160: '톰이랑',
#  161: '나한테',
#  162: '거의',
#  163: '뭘',
#  164: '세',
#  165: '절대',
#  166: '그를',
#  167: '제가',
#  168: '시간이',
#  169: '좋아해.',
#  170: '싶다.',
#  171: '거',
#  172: '어디',
#  173: '해야',
#  174: '거기에',
#  175: '몰랐어.',
#  176: '싶은',
#  177: '웃었어.',
#  178: '여기서',
#  179: '시간을',
#  180: '꽤',
#  181: '톰',
#  182: '본',
#  183: '거라고',
#  184: '사람들이',
#  185: '눈이',
#  186: '사람',
#  187: '위해',
#  188: '갔다.',
#  189: '진짜',
#  190: '보여.',
#  191: '일이',
#  192: '있나요?',
#  193: '모른다.',
#  194: '바로',
#  195: '봐.',
#  196: '저는',
#  197: '가고',
#  198: '좋다.',
#  199: '돈이',
#  200: '이제',
#  201: '필요하다.',
#  202: '모두가',
#  203: '좋아해?',
#  204: '매우',
#  205: '나에게',
#  206: '그런',
#  207: '없었어.',
#  208: '당신의',
#  209: '살고',
#  210: '가지고',
#  211: '매일',
#  212: '생각한다.',
#  213: '아무것도',
#  214: '정말로',
#  215: '열심히',
#  216: '와.',
#  217: '자신이',
#  218: '돼.',
#  219: '뭐야?',
#  220: '고양이를',
#  221: '좋아한다.',
#  222: '아니다.',
#  223: '말',
#  224: '같은',
#  225: '아는',
#  226: '했는데.',
#  227: '호주에',
#  228: '우리한테',
#  229: '줘.',
#  230: '그들이',
#  231: '비가',
#  232: '누군가',
#  233: '제',
#  234: '살',
#  235: '일을',
#  236: '될',
#  237: '언제',
#  238: '별로',
#  239: '필요가',
#  240: '배우고',
#  241: '동안',
#  242: '생각하지',
#  243: '함께',
#  244: '죽었어.',
#  245: '마세요.',
#  246: '빨리',
#  247: '말이',
#  248: '그냥',
#  249: '몰라.',
#  250: '안에',
#  251: '고양이는',
#  252: '있을까?',
#  253: '배웠어.',
#  254: '너희',
#  255: '훨씬',
#  256: '프랑스어로',
#  257: '당신이',
#  258: '나이에',
#  259: '비해',
#  260: '왔어.',
#  261: '말해.',
#  262: '이렇게',
#  263: '있어봐.',
#  264: '또',
#  265: '좋아.',
#  266: '갖고',
#  267: '있습니다.',
#  268: '프랑스어는',
#  269: '보인다.',
#  270: '모두들',
#  271: '있니?',
#  272: '곧',
#  273: '전혀',
#  274: '말했어.',
#  275: '있습니까?',
#  276: '좋아하지',
#  277: '어디서',
#  278: '좋겠어.',
#  279: '차를',
#  280: '생각해?',
#  281: '중',
#  282: '다른',
#  283: '알아.',
#  284: '사람을',
#  285: '키가',
#  286: '일은',
#  287: '기분이',
#  288: '보고',
#  289: '있어요.',
#  290: '메리의',
#  291: '언어를',
#  292: '도움이',
#  293: '이미',
#  294: '메리에게',
#  295: '조금',
#  296: '자주',
#  297: '너에게',
#  298: '먹고',
#  299: '이런',
#  300: '생각해.',
#  301: '우리의',
#  302: '프랑스',
#  303: '쓰고',
#  304: '싶어?',
#  305: '돈을',
#  306: '생각했어.',
#  307: '말았어야',
#  308: '탐은',
#  309: '다음',
#  310: '배우는',
#  311: '없는',
#  312: '알았어.',
#  313: '알아?',
#  314: '싫다.',
#  315: '나랑',
#  316: '수가',
#  317: '싫어.',
#  318: '같다.',
#  319: '우리에게',
#  320: '노래를',
#  321: '캐나다',
#  322: '어디로',
#  323: '그녀의',
#  324: '아마',
#  325: '무엇을',
#  326: '두',
#  327: '있지?',
#  328: '시작했다.',
#  329: '고양이',
#  330: '지난',
#  331: '한번',
#  332: '그에게',
#  333: '가는',
#  334: '혼자',
#  335: '입고',
#  336: '사람이야.',
#  337: '집을',
#  338: '없이',
#  339: '있다고',
#  340: '알았다.',
#  341: '있는지',
#  342: '번',
#  343: '서로',
#  344: '말하지',
#  345: '이렇게나',
#  346: '조용히',
#  347: '참',
#  348: '먹지',
#  349: '돼?',
#  350: '시간',
#  351: '너의',
#  352: '물',
#  353: '먹을',
#  354: '손을',
#  355: '이것을',
#  356: '아냐.',
#  357: '산다.',
#  358: '싶어',
#  359: '텐데.',
#  360: '문을',
#  361: '그치?',
#  362: '도와줄',
#  363: '보스턴에서',
#  364: '그녀가',
#  365: '되어',
#  366: '아침',
#  367: '가끔',
#  368: '좋겠다.',
#  369: '수는',
#  370: '보내고',
#  371: '가본',
#  372: '아름다운',
#  373: '들어.',
#  374: '거짓말을',
#  375: '뭐',
#  376: '수가!',
#  377: '당신',
#  378: '어때?',
#  379: '앉아',
#  380: '그거',
#  381: '그럴',
#  382: '사랑한다.',
#  383: '듣고',
#  384: '떠났다.',
#  385: '당신을',
#  386: '일하는',
#  387: '그것은',
#  388: '일하고',
#  389: '꿈을',
#  390: '물이',
#  391: '수도',
#  392: '톰도',
#  393: '물을',
#  394: '않아?',
#  395: '줄래?',
#  396: '쓴다.',
#  397: '봤어.',
#  398: '먹는',
#  399: '나도',
#  400: '뿐이야.',
#  401: '어디에',
#  402: '죽을',
#  403: '볼',
#  404: '너를',
#  405: '일찍',
#  406: '명',
#  407: '단지',
#  408: '자기가',
#  409: '한때',
#  410: '쓰는',
#  411: '싶었어.',
#  412: '오늘은',
#  413: '개를',
#  414: '못했다.',
#  415: '한번이라도',
#  416: '있다는',
#  417: '컴퓨터를',
#  418: '것에',
#  419: '중에',
#  420: '말하는',
#  421: '하는지',
#  422: '그다지',
#  423: '공부하는',
#  424: '나보다',
#  425: '데',
#  426: '파티에',
#  427: '않은데.',
#  428: '작은',
#  429: '줄은',
#  430: '문제는',
#  431: '저걸',
#  432: '혼자서',
#  433: '우리를',
#  434: '가자.',
#  435: '제발',
#  436: '누구',
#  437: '재미있다.',
#  438: '최선을',
#  439: '고양이가',
#  440: '머리가',
#  441: '늙었어.',
#  442: '계신가요?',
#  443: '도울',
#  444: '원한다.',
#  445: '찾고',
#  446: '조심해.',
#  447: '잘해.',
#  448: '쉽지',
#  449: '들어',
#  450: '된다.',
#  451: '오래된',
#  452: '침대에',
#  453: '공부하고',
#  454: '샀어.',
#  455: '얘기',
#  456: '아이들이',
#  457: '건가요?',
#  458: '사람의',
#  459: '돌아올',
#  460: '수영을',
#  461: '떠나야',
#  462: '못해.',
#  463: '이길',
#  464: '거라는',
#  465: '만난',
#  466: '월요일에',
#  467: '싶어하지',
#  468: '많다.',
#  469: '열쇠를',
#  470: '보았다.',
#  471: '것처럼',
#  472: '이야기를',
#  473: '들었다.',
#  474: '사실이야.',
#  475: '메리와',
#  476: '싶어해.',
#  477: '제일',
#  478: '뭔가가',
#  479: '딸은',
#  480: '있어서',
#  481: '개',
#  482: '실수를',
#  483: '갔으면',
#  484: '엄청',
#  485: '거지?',
#  486: '살아.',
#  487: '모자를',
#  488: '계란',
#  489: '메리',
#  490: '방',
#  491: '척',
#  492: '간다.',
#  493: '문제를',
#  494: '모르겠어.',
#  495: '대부분의',
#  496: '가',
#  497: '온',
#  498: '메리한테',
#  499: '오래',
#  500: '것이라고',
#  501: '보통',
#  502: '어려움을',
#  503: '일에',
#  504: '가.',
#  505: '저리',
#  506: '떠났어.',
#  507: '죄송합니다.',
#  508: '좋아요.',
#  509: '보세요.',
#  510: '가져.',
#  511: '와인',
#  512: '진실을',
#  513: '커.',
#  514: '괜찮은',
#  515: '감옥에',
#  516: '노래',
#  517: '아무',
#  518: '말도',
#  519: '차',
#  520: '나의',
#  521: '배를',
#  522: '새로운',
#  523: '싫어한다.',
#  524: '음악을',
#  525: '중독자야.',
#  526: '누구나',
#  527: '걸렸어.',
#  528: '걸렸다.',
#  529: '이름은',
#  530: '갔어.',
#  531: '필요해.',
#  532: '나에게는',
#  533: '여자',
#  534: '있어요?',
#  535: '점심',
#  536: '맥주를',
#  537: '사람이다.',
#  538: '해',
#  539: '피아노를',
#  540: '누구도',
#  541: '생각',
#  542: '싶어한다.',
#  543: '뭐가',
#  544: '여자가',
#  545: '영어를',
#  546: '올',
#  547: '줬어.',
#  548: '담배를',
#  549: '진짜로',
#  550: '노력했어.',
#  551: '방은',
#  552: '중이야.',
#  553: '꿈은',
#  554: '사실을',
#  555: '원숭이는',
#  556: '그곳에',
#  557: '더이상',
#  558: '유일한',
#  559: '살이',
#  560: '배울',
#  561: '테니스를',
#  562: '생각해',
#  563: '마리가',
#  564: '친구를',
#  565: '구성되어',
#  566: '어려워.',
#  567: '집에서',
#  568: '저녁을',
#  569: '지',
#  570: '있었으면',
#  571: '되고',
#  572: '작년에',
#  573: '저런',
#  574: '영어로',
#  575: '책은',
#  576: '방법을',
#  577: '같지',
#  578: '바란다.',
#  579: '여섯',
#  580: '누구야?',
#  581: '며칠',
#  582: '말라고',
#  583: '만약',
#  584: '새',
#  585: '할지',
#  586: '짓을',
#  587: '할아버지는',
#  588: '생일',
#  589: '없다고',
#  590: '버스가',
#  591: '가치가',
#  592: '결혼했어.',
#  593: '방법이',
#  594: '않는',
#  595: '같진',
#  596: '아니라',
#  597: '명의',
#  598: '시작해.',
#  599: '뭐라고',
#  600: '일해.',
#  601: '고마워.',
#  602: '그만해.',
#  603: '새가',
#  604: '개가',
#  605: '바라.',
#  606: '읽어.',
#  607: '울었어.',
#  608: '우릴',
#  609: '사실이야?',
#  610: '쳐.',
#  611: '춤을',
#  612: '부탁해.',
#  613: '남아',
#  614: '사람들',
#  615: '썼어.',
#  616: '물에',
#  617: '숨을',
#  618: '먹었다.',
#  619: '되나요?',
#  620: '톰.',
#  621: '그녀를',
#  622: '걱정',
#  623: '아니라고',
#  624: '않아요.',
#  625: '잠이',
#  626: '감기에',
#  627: '아름답다.',
#  628: '사실이',
#  629: '키우고',
#  630: '앉았다.',
#  631: '화가',
#  632: '도와',
#  633: '마음이',
#  634: '저를',
#  635: '방을',
#  636: '좋아해요?',
#  637: '남자를',
#  638: '왔다.',
#  639: '감기',
#  640: '형제가',
#  641: '인생은',
#  642: '사라졌어.',
#  643: '자고',
#  644: '친다.',
#  645: '은행',
#  646: '도와주지',
#  647: '때문에',
#  648: '좋아?',
#  649: '빌려',
#  650: '눈을',
#  651: '들었어.',
#  652: '세게',
#  653: '안경을',
#  654: '보냈어.',
#  655: '지하철로',
#  656: '갈게.',
#  657: '선생님이',
#  658: '시계를',
#  659: '전부야.',
#  660: '됐어.',
#  661: '지도',
#  662: '보였어.',
#  663: '인간이',
#  664: '조언을',
#  665: '걔는',
#  666: '학교를',
#  667: '전',
#  668: '태어났어.',
#  669: '어쩔',
#  670: '나이가',
#  671: '영어',
#  672: '지난주에',
#  673: '봤다.',
#  674: '만났다.',
#  675: '싶니?',
#  676: '있길',
#  677: '지난밤에',
#  678: '나중에',
#  679: '나와',
#  680: '몇몇',
#  681: '저게',
#  682: '약은',
#  683: '사실은',
#  684: '훌륭한',
#  685: '머리를',
#  686: '생일은',
#  687: '자신을',
#  688: '도움을',
#  689: '30분에',
#  690: '눈물로',
#  691: '가득했다.',
#  692: '시계는',
#  693: '생각을',
#  694: '하면',
#  695: '어느',
#  696: '마음에',
#  697: '아파트에서',
#  698: '치는',
#  699: '말하길',
#  700: '외로워',
#  701: '탔다.',
#  702: '동물이야.',
#  703: '된',
#  704: '합니다.',
#  705: '선생님이야.',
#  706: '위험한',
#  707: '가진',
#  708: '참을',
#  709: '운전하는',
#  710: '후에',
#  711: '말은',
#  712: '너랑',
#  713: '없습니다.',
#  714: '친구가',
#  715: '대한',
#  716: '너와',
#  717: '어떠한',
#  718: '뭔가를',
#  719: '줘야',
#  720: '마음을',
#  721: '거리를',
#  722: '하려고',
#  723: '소설을',
#  724: '정도로',
#  725: '시달리고',
#  726: '해?',
#  727: '처음',
#  728: '오스트레일리아에',
#  729: '모르겠다.',
#  730: '소프트웨어',
#  731: '있지',
#  732: '산',
#  733: '질문에',
#  734: '외로울',
#  735: '소식을',
#  736: '빼고',
#  737: '쓸',
#  738: '믿을',
#  739: '크리스마스',
#  740: '밤',
#  741: '오직',
#  742: '한다고',
#  743: '세상에',
#  744: '건지',
#  745: '내년에',
#  746: '경찰은',
#  747: '보스턴을',
#  748: '마지막',
#  749: '안다는',
#  750: '수영하러',
#  751: '말한',
#  752: '없어?',
#  753: '냉장고에',
#  754: '하기',
#  755: '어렸을',
#  756: '진정해.',
#  757: '잃어버렸다.',
#  758: '이겼어.',
#  759: '달린다.',
#  760: '마셔.',
#  761: '늦었어.',
#  762: '죽었다.',
#  763: '믿어.',
#  764: '그들을',
#  765: '내렸어.',
#  766: '당장',
#  767: '쳤어.',
#  768: '해봐.',
#  769: '하나',
#  770: '와!',
#  771: '마!',
#  772: '천천히',
#  773: '먹어.',
#  774: '가만히',
#  775: '집으로',
#  776: '인간이야.',
#  777: '기분',
#  778: '기억하고',
#  779: '남자',
#  780: '아프다.',
#  781: '공부해.',
#  782: '소리를',
#  783: '늦잠잤어.',
#  784: '빠져',
#  785: '아파요.',
#  786: '것입니다.',
#  787: '이해해.',
#  788: '끝냈어.',
#  789: '죽고',
#  790: '해줘.',
#  791: '비명을',
#  792: '자랐다.',
#  793: '울고',
#  794: '좋아합니다.',
#  795: '집이',
#  796: '나.',
#  797: '과학은',
#  798: '늦어서',
#  799: '싫어해.',
#  800: '귀신이',
#  801: '실제로',
#  802: '받았다.',
#  803: '사는',
#  804: '될까?',
#  805: '피가',
#  806: '운이',
#  807: '써.',
#  808: '너도',
#  809: '될까요?',
#  810: '생선',
#  811: '부르고',
#  812: '어째서',
#  813: '마리를',
#  814: '샀다.',
#  815: '누군지',
#  816: '떠난',
#  817: '일요일에',
#  818: '일한다.',
#  819: '근처에',
#  820: '아니었다.',
#  821: '책이',
#  822: '없어요.',
#  823: '어딨어?',
#  824: '전부',
#  825: '빠르게',
#  826: '일곱',
#  827: '일어났어.',
#  828: '자동차를',
#  829: '가르쳤어.',
#  830: '남자야.',
#  831: '쉽게',
#  832: '내버려',
#  833: '나갔다.',
#  834: '이것이',
#  835: '거미를',
#  836: '걸.',
#  837: '결코',
#  838: '맞다.',
#  839: '돈',
#  840: '낫다.',
#  841: '요리를',
#  842: '빨간색',
#  843: '있다면',
#  844: '좋을',
#  845: '더워졌다.',
#  846: '믿지',
#  847: '거미가',
#  848: '소심한',
#  849: '하나를',
#  850: '좋겠어?',
#  851: '다시는',
#  852: '연설은',
#  853: '있었어?',
#  854: '가족은',
#  855: '뻔',
#  856: '미안한데,',
#  857: '거기서',
#  858: '원숭이가',
#  859: '기다렸다.',
#  860: '여전히',
#  861: '개의',
#  862: '저희',
#  863: '밤에',
#  864: '과학이',
#  865: '기다리고',
#  866: '뛰어나다고',
#  867: '사고',
#  868: '그것에',
#  869: '열',
#  870: '궁금하게',
#  871: '그렇지',
#  872: '자신의',
#  873: '만났어.',
#  874: '종종',
#  875: '이상하게',
#  876: '확실히',
#  877: '마약',
#  878: '중독성',
#  879: '궁금하네.',
#  880: '싶습니다.',
#  881: '2시',
#  882: '사회적인',
#  883: '듣지',
#  884: '기회를',
#  885: '배워야',
#  886: '문제가',
#  887: '단어야.',
#  888: '커피를',
#  889: '들지',
#  890: '꿨어.',
#  891: '딸이',
#  892: '학교',
#  893: '없이는',
#  894: '밖에',
#  895: '시작했어.',
#  896: '피자',
#  897: '원하는',
#  898: '사과',
#  899: '않은',
#  900: '시간에',
#  901: '사진',
#  902: '하도록',
#  903: '저녁',
#  904: '이상한',
#  905: '기분이야.',
#  906: '좋지',
#  907: '곳에',
#  908: '더하기',
#  909: '말해',
#  910: '옷을',
#  911: '속에',
#  912: '중에서',
#  913: '공부해야',
#  914: '빵은',
#  915: '직접',
#  916: '있으신가요?',
#  917: '보지',
#  918: '걸릴',
#  919: '두는',
#  920: '되었어.',
#  921: '막',
#  922: '나쁜',
#  923: '작아.',
#  924: '어려.',
#  925: '달에',
#  926: '정확히',
#  927: '기타를',
#  928: '먹을래?',
#  929: '오지',
#  930: '당신과',
#  931: '관심',
#  932: '긴',
#  933: '숙제를',
#  934: '날씨가',
#  935: '읽고',
#  936: '알려',
#  937: '완전히',
#  938: '알게',
#  939: '때까지',
#  940: '간',
#  941: '읽지',
#  942: '대화할',
#  943: '누군가가',
#  944: '체스를',
#  945: '되지',
#  946: '빠질',
#  947: '많아.',
#  948: '진단받았어.',
#  949: '했다는',
#  950: '일주일에',
#  951: '쓰지',
#  952: '좋았을',
#  953: '누나는',
#  954: '주고',
#  955: '제대로',
#  956: '종류의',
#  957: '주었다.',
#  958: '말씀해',
#  959: '주시겠어요?',
#  960: '답할',
#  961: '과학',
#  962: '떠날',
#  963: '학교에서',
#  964: '만나고',
#  965: '돌아가셨다.',
#  966: '문장은',
#  967: '저한테',
#  968: '있다',
#  969: '해서',
#  970: '아침을',
#  971: '생각했다.',
#  972: '때가',
#  973: '번도',
#  974: '생각하는',
#  975: '생일을',
#  976: '직업을',
#  977: '가능성이',
#  978: '크리스마스를',
#  979: '만한',
#  980: '맞는',
#  981: '일주일',
#  982: '모른다고',
#  983: '호주에서',
#  984: '시험에',
#  985: '말할',
#  986: '오늘밤',
#  987: '일',
#  988: '부탁했다.',
#  989: '때는',
#  990: '우리랑',
#  991: '사실',
#  992: '딱히',
#  993: '것보다',
#  994: '방에',
#  995: '다들',
#  996: '다음에',
#  997: '원인은',
#  998: '혼자인',
#  999: '싶었다.',
#  1000: '상상도',
#  ...}

# %%
kor_num_words = min(VOCAB_SIZE, len(kor_tokenizer.index_word))
kor_max_len = max([len(seq) for seq in kor_inputs_seq])

# %% [markdown]
# ### 패딩처리
#
# - 인코더 padding
# - 디코더 padding

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

eng_inputs_padded = pad_sequences(eng_inputs_seq, maxlen=eng_max_len, padding='pre')
kor_inputs_padded = pad_sequences(kor_inputs_seq, maxlen=kor_max_len, padding='post')
kor_targets_padded = pad_sequences(kor_targets_seq, maxlen=kor_max_len, padding='post')

eng_inputs_padded.shape, kor_inputs_padded.shape, kor_targets_padded.shape
# Out:
# ((5890, 101), (5890, 90), (5890, 90))

# %% [markdown]
# ### 모델 학습
#
# `encoder + decoder(teacher_forcing)` 구조의 모델 생성 및 학습

# %% [markdown]
# ##### Embedding Layer

# %%
with open('./glove.6B.100d.txt', 'r', encoding='UTF-8') as f:
    for i, vects in enumerate(f):
        print(vects)
        if i == 5:
            break
# Out:
# the -0.038194 -0.24487 0.72812 -0.39961 0.083172 0.043953 -0.39141 0.3344 -0.57545 0.087459 0.28787 -0.06731 0.30906 -0.26384 -0.13231 -0.20757 0.33395 -0.33848 -0.31743 -0.48336 0.1464 -0.37304 0.34577 0.052041 0.44946 -0.46971 0.02628 -0.54155 -0.15518 -0.14107 -0.039722 0.28277 0.14393 0.23464 -0.31021 0.086173 0.20397 0.52624 0.17164 -0.082378 -0.71787 -0.41531 0.20335 -0.12763 0.41367 0.55187 0.57908 -0.33477 -0.36559 -0.54857 -0.062892 0.26584 0.30205 0.99775 -0.80481 -3.0243 0.01254 -0.36942 2.2167 0.72201 -0.24978 0.92136 0.034514 0.46745 1.1079 -0.19358 -0.074575 0.23353 -0.052062 -0.22044 0.057162 -0.15806 -0.30798 -0.41625 0.37972 0.15006 -0.53212 -0.2055 -1.2526 0.071624 0.70565 0.49744 -0.42063 0.26148 -1.538 -0.30223 -0.073438 -0.28312 0.37104 -0.25217 0.016215 -0.017099 -0.38984 0.87424 -0.72569 -0.51058 -0.52028 -0.1459 0.8278 0.27062
#
# , -0.10767 0.11053 0.59812 -0.54361 0.67396 0.10663 0.038867 0.35481 0.06351 -0.094189 0.15786 -0.81665 0.14172 0.21939 0.58505 -0.52158 0.22783 -0.16642 -0.68228 0.3587 0.42568 0.19021 0.91963 0.57555 0.46185 0.42363 -0.095399 -0.42749 -0.16567 -0.056842 -0.29595 0.26037 -0.26606 -0.070404 -0.27662 0.15821 0.69825 0.43081 0.27952 -0.45437 -0.33801 -0.58184 0.22364 -0.5778 -0.26862 -0.20425 0.56394 -0.58524 -0.14365 -0.64218 0.0054697 -0.35248 0.16162 1.1796 -0.47674 -2.7553 -0.1321 -0.047729 1.0655 1.1034 -0.2208 0.18669 0.13177 0.15117 0.7131 -0.35215 0.91348 0.61783 0.70992 0.23955 -0.14571 -0.37859 -0.045959 -0.47368 0.2385 0.20536 -0.18996 0.32507 -1.1112 -0.36341 0.98679 -0.084776 -0.54008 0.11726 -1.0194 -0.24424 0.12771 0.013884 0.080374 -0.35414 0.34951 -0.7226 0.37549 0.4441 -0.99059 0.61214 -0.35111 -0.83155 0.45293 0.082577
#
# . -0.33979 0.20941 0.46348 -0.64792 -0.38377 0.038034 0.17127 0.15978 0.46619 -0.019169 0.41479 -0.34349 0.26872 0.04464 0.42131 -0.41032 0.15459 0.022239 -0.64653 0.25256 0.043136 -0.19445 0.46516 0.45651 0.68588 0.091295 0.21875 -0.70351 0.16785 -0.35079 -0.12634 0.66384 -0.2582 0.036542 -0.13605 0.40253 0.14289 0.38132 -0.12283 -0.45886 -0.25282 -0.30432 -0.11215 -0.26182 -0.22482 -0.44554 0.2991 -0.85612 -0.14503 -0.49086 0.0082973 -0.17491 0.27524 1.4401 -0.21239 -2.8435 -0.27958 -0.45722 1.6386 0.78808 -0.55262 0.65 0.086426 0.39012 1.0632 -0.35379 0.48328 0.346 0.84174 0.098707 -0.24213 -0.27053 0.045287 -0.40147 0.11395 0.0062226 0.036673 0.018518 -1.0213 -0.20806 0.64072 -0.068763 -0.58635 0.33476 -1.1432 -0.1148 -0.25091 -0.45907 -0.096819 -0.17946 -0.063351 -0.67412 -0.068895 0.53604 -0.87773 0.31802 -0.39242 -0.23394 0.47298 -0.028803
#
# of -0.1529 -0.24279 0.89837 0.16996 0.53516 0.48784 -0.58826 -0.17982 -1.3581 0.42541 0.15377 0.24215 0.13474 0.41193 0.67043 -0.56418 0.42985 -0.012183 -0.11677 0.31781 0.054177 -0.054273 0.35516 -0.30241 0.31434 -0.33846 0.71715 -0.26855 -0.15837 -0.47467 0.051581 -0.33252 0.15003 -0.1299 -0.54617 -0.37843 0.64261 0.82187 -0.080006 0.078479 -0.96976 -0.57741 0.56491 -0.39873 -0.057099 0.19743 0.065706 -0.48092 -0.20125 -0.40834 0.39456 -0.02642 -0.11838 1.012 -0.53171 -2.7474 -0.042981 -0.74849 1.7574 0.59085 0.04885 0.78267 0.38497 0.42097 0.67882 0.10337 0.6328 -0.026595 0.58647 -0.44332 0.33057 -0.12022 -0.55645 0.073611 0.20915 0.43395 -0.012761 0.089874 -1.7991 0.084808 0.77112 0.63105 -0.90685 0.60326 -1.7515 0.18596 -0.50687 -0.70203 0.66578 -0.81304 0.18712 -0.018488 -0.26757 0.727 -0.59363 -0.34839 -0.56094 -0.591 1.0039 0.20664
#
# to -0.1897 0.050024 0.19084 -0.049184 -0.089737 0.21006 -0.54952 0.098377 -0.20135 0.34241 -0.092677 0.161 -0.13268 -0.2816 0.18737 -0.42959 0.96039 0.13972 -1.0781 0.40518 0.50539 -0.55064 0.4844 0.38044 -0.0029055 -0.34942 -0.099696 -0.78368 1.0363 -0.2314 -0.47121 0.57126 -0.21454 0.35958 -0.48319 1.0875 0.28524 0.12447 -0.039248 -0.076732 -0.76343 -0.32409 -0.5749 -1.0893 -0.41811 0.4512 0.12112 -0.51367 -0.13349 -1.1378 -0.28768 0.16774 0.55804 1.5387 0.018859 -2.9721 -0.24216 -0.92495 2.1992 0.28234 -0.3478 0.51621 -0.43387 0.36852 0.74573 0.072102 0.27931 0.92569 -0.050336 -0.85856 -0.1358 -0.92551 -0.33991 -1.0394 -0.067203 -0.21379 -0.4769 0.21377 -0.84008 0.052536 0.59298 0.29604 -0.67644 0.13916 -1.5504 -0.20765 0.7222 0.52056 -0.076221 -0.15194 -0.13134 0.058617 -0.31869 -0.61419 -0.62393 -0.41548 -0.038175 -0.39804 0.47647 -0.15983
#
# and -0.071953 0.23127 0.023731 -0.50638 0.33923 0.1959 -0.32943 0.18364 -0.18057 0.28963 0.20448 -0.5496 0.27399 0.58327 0.20468 -0.49228 0.19974 -0.070237 -0.88049 0.29485 0.14071 -0.1009 0.99449 0.36973 0.44554 0.28998 -0.1376 -0.56365 -0.029365 -0.4122 -0.25269 0.63181 -0.44767 0.24363 -0.10813 0.25164 0.46967 0.3755 -0.23613 -0.14129 -0.44537 -0.65737 -0.042421 -0.28636 -0.28811 0.063766 0.20281 -0.53542 0.41307 -0.59722 -0.38614 0.19389 -0.17809 1.6618 -0.011819 -2.3737 0.058427 -0.2698 1.2823 0.81925 -0.22322 0.72932 -0.053211 0.43507 0.85011 -0.42935 0.92664 0.39051 1.0585 -0.24561 -0.18265 -0.5328 0.059518 -0.66019 0.18991 0.28836 -0.2434 0.52784 -0.65762 -0.14081 1.0491 0.5134 -0.23816 0.69895 -1.4813 -0.2487 -0.17936 -0.059137 -0.08056 -0.48782 0.014487 -0.6259 -0.32367 0.41862 -1.0807 0.46742 -0.49931 -0.71895 0.86894 0.19539

# %%
import numpy as np

def make_embedding_matrix(num_words, embedding_dim, tokenizer, file_path):
    embedding_matrix = np.zeros((num_words + 1, embedding_dim))

    pretrained_embedding = {}

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            word, *vects = line.split()
            vects = np.array(vects, dtype=np.float32)
            pretrained_embedding[word] = vects

    for word, index in tokenizer.word_index.items():
        vects_ = pretrained_embedding.get(word)
        if vects_ is not None:
            embedding_matrix[index] = vects_

    return embedding_matrix

# %%
EMBEDDING_DIM = 100

en_embedding_matrix = make_embedding_matrix(
    eng_num_words,
    EMBEDDING_DIM,
    eng_tokenizer,
    'glove.6B.100d.txt'
)

# %%
en_embedding_matrix.shape
# Out:
# (3201, 100)

# %%
eng_word_index = ['<pad>'] + list(eng_tokenizer.index_word.values())
eng_word_index
# Out:
# ['<pad>',
#  '<oov>',
#  'i',
#  'tom',
#  'to',
#  'you',
#  'the',
#  'is',
#  'a',
#  'that',
#  'do',
#  'in',
#  'this',
#  'was',
#  'have',
#  'he',
#  "i'm",
#  'my',
#  'are',
#  'of',
#  "don't",
#  'it',
#  'me',
#  'be',
#  'your',
#  'like',
#  'for',
#  'what',
#  'want',
#  'think',
#  'we',
#  'know',
#  'not',
#  'mary',
#  'his',
#  'there',
#  'how',
#  'can',
#  'french',
#  'and',
#  'very',
#  'has',
#  "it's",
#  'at',
#  'go',
#  'with',
#  'she',
#  'did',
#  "didn't",
#  'on',
#  'here',
#  'why',
#  'going',
#  'been',
#  'all',
#  'no',
#  'as',
#  'really',
#  'help',
#  'please',
#  'time',
#  "can't",
#  'they',
#  'will',
#  'him',
#  "isn't",
#  'one',
#  "you're",
#  'if',
#  'about',
#  'good',
#  "that's",
#  'who',
#  'too',
#  "doesn't",
#  'up',
#  'had',
#  'were',
#  'where',
#  'would',
#  'from',
#  "tom's",
#  'said',
#  'need',
#  'something',
#  'when',
#  'us',
#  'tell',
#  'never',
#  'home',
#  'now',
#  'still',
#  'more',
#  'school',
#  'so',
#  'an',
#  'should',
#  'come',
#  'than',
#  'some',
#  'sorry',
#  'but',
#  'ever',
#  'get',
#  'work',
#  'out',
#  "i'll",
#  "i've",
#  'three',
#  'by',
#  'boston',
#  'take',
#  'keep',
#  'stop',
#  'just',
#  'doing',
#  'thought',
#  'hard',
#  'love',
#  'old',
#  'many',
#  'last',
#  'people',
#  'right',
#  'any',
#  'used',
#  'say',
#  'money',
#  'much',
#  'day',
#  'speak',
#  'her',
#  'today',
#  'got',
#  "we're",
#  'tomorrow',
#  'learn',
#  'see',
#  'everyone',
#  'favorite',
#  'well',
#  'cat',
#  'could',
#  'person',
#  'our',
#  'water',
#  'yesterday',
#  'live',
#  'australia',
#  'late',
#  'back',
#  'feel',
#  'anything',
#  'lonely',
#  'buy',
#  'room',
#  'wanted',
#  'house',
#  "let's",
#  'again',
#  'book',
#  'lot',
#  'long',
#  'made',
#  'does',
#  'left',
#  'eat',
#  'dog',
#  'car',
#  'next',
#  'look',
#  'knows',
#  "i'd",
#  "what's",
#  'only',
#  'told',
#  'or',
#  'hate',
#  'give',
#  'year',
#  'wants',
#  'stay',
#  'came',
#  'read',
#  'alone',
#  'nobody',
#  'went',
#  'two',
#  'language',
#  'every',
#  'way',
#  'man',
#  'problem',
#  'years',
#  "he's",
#  'believe',
#  "won't",
#  'before',
#  'job',
#  'leave',
#  'understand',
#  "wasn't",
#  'friends',
#  'world',
#  'true',
#  'study',
#  'use',
#  'looks',
#  'everybody',
#  'play',
#  'wish',
#  'yet',
#  'always',
#  'make',
#  'these',
#  'done',
#  'saw',
#  'quite',
#  'life',
#  'better',
#  'most',
#  'down',
#  'am',
#  'new',
#  'easy',
#  'bed',
#  'into',
#  'night',
#  'anymore',
#  'away',
#  'died',
#  'lie',
#  'talk',
#  'let',
#  'wrong',
#  'asked',
#  'cold',
#  'married',
#  'knew',
#  'science',
#  'bought',
#  'may',
#  'english',
#  "there's",
#  'sure',
#  'other',
#  'try',
#  'nice',
#  'after',
#  'them',
#  'remember',
#  'busy',
#  'beautiful',
#  'both',
#  'everything',
#  'took',
#  'teacher',
#  'heard',
#  'often',
#  'children',
#  "should've",
#  'human',
#  'nothing',
#  'happy',
#  'met',
#  'brother',
#  'father',
#  'same',
#  'little',
#  'having',
#  'wait',
#  'lost',
#  'red',
#  'looking',
#  'first',
#  'someone',
#  'cats',
#  'sleep',
#  'studying',
#  'soon',
#  'food',
#  'week',
#  'fun',
#  'answer',
#  'find',
#  'sing',
#  'god',
#  'over',
#  'yourself',
#  "we'll",
#  'young',
#  'learned',
#  'pretty',
#  "you'll",
#  'being',
#  'difficult',
#  'birthday',
#  'off',
#  'drink',
#  'sit',
#  'tried',
#  'watch',
#  'trying',
#  'blood',
#  'drive',
#  'working',
#  'might',
#  'name',
#  'loves',
#  'meet',
#  'happened',
#  'afraid',
#  'police',
#  'door',
#  'hope',
#  'getting',
#  'without',
#  'age',
#  'hours',
#  'call',
#  'must',
#  'morning',
#  'best',
#  'tired',
#  'sister',
#  'bus',
#  'dark',
#  'lives',
#  'five',
#  'days',
#  'mother',
#  'books',
#  'idea',
#  'seen',
#  'students',
#  'party',
#  'class',
#  'wearing',
#  'wine',
#  'mind',
#  'fish',
#  'suicide',
#  'rest',
#  'change',
#  'important',
#  'almost',
#  "aren't",
#  'phone',
#  'medicine',
#  'small',
#  'times',
#  'question',
#  'able',
#  'woman',
#  'says',
#  'tonight',
#  'few',
#  "haven't",
#  'learning',
#  'six',
#  'software',
#  'open',
#  'anyone',
#  'ok',
#  'die',
#  'crying',
#  'walk',
#  'anybody',
#  'reading',
#  'great',
#  'hear',
#  'interesting',
#  'needs',
#  'dream',
#  'write',
#  'swim',
#  'speaks',
#  'moon',
#  'already',
#  'gave',
#  'killed',
#  'put',
#  "you've",
#  'win',
#  'snow',
#  'family',
#  'enough',
#  'longer',
#  'wonder',
#  'ago',
#  'thinks',
#  "wouldn't",
#  "who's",
#  'place',
#  'things',
#  'hold',
#  'show',
#  'works',
#  'forget',
#  'ready',
#  'hands',
#  'laughed',
#  'ask',
#  'bad',
#  'felt',
#  'looked',
#  'called',
#  'kissed',
#  'mine',
#  'music',
#  'hot',
#  'talking',
#  'move',
#  'real',
#  'languages',
#  'bank',
#  'subway',
#  'canadian',
#  'dictionary',
#  'later',
#  "where's",
#  'seems',
#  'eating',
#  'big',
#  'visit',
#  'computer',
#  'tennis',
#  'social',
#  'word',
#  'thing',
#  "couldn't",
#  "mary's",
#  'breakfast',
#  'christmas',
#  'matter',
#  'under',
#  'grandfather',
#  'chance',
#  'swimming',
#  'run',
#  'fire',
#  'quit',
#  'pay',
#  'start',
#  'careful',
#  'blue',
#  'around',
#  'eggs',
#  'meat',
#  'free',
#  'yours',
#  'stupid',
#  'apples',
#  'news',
#  'friend',
#  'mean',
#  'white',
#  'plan',
#  'doctor',
#  'advice',
#  'fact',
#  'playing',
#  'act',
#  'child',
#  'river',
#  'korea',
#  'accident',
#  'which',
#  'rich',
#  "you'd",
#  'station',
#  'worth',
#  'won',
#  'listen',
#  'lied',
#  'cried',
#  'care',
#  'forgive',
#  'beer',
#  'sick',
#  'singing',
#  'flowers',
#  'fell',
#  'myself',
#  'dangerous',
#  "they're",
#  'those',
#  'sleepy',
#  'found',
#  'hair',
#  'piano',
#  'mistake',
#  'kind',
#  'fast',
#  'borrow',
#  'eyes',
#  'girl',
#  'boy',
#  'spiders',
#  'gone',
#  'monday',
#  "we've",
#  'tv',
#  'thirty',
#  'story',
#  'boat',
#  'watching',
#  'acting',
#  'country',
#  'apartment',
#  'decided',
#  'dinner',
#  'four',
#  'month',
#  'daughter',
#  'ridiculous',
#  'high',
#  'parents',
#  'assure',
#  'point',
#  'spend',
#  'possible',
#  'probably',
#  'vacation',
#  'hurry',
#  'fly',
#  'tall',
#  'quiet',
#  'inside',
#  'ate',
#  'girls',
#  'addicted',
#  'clean',
#  'full',
#  'horse',
#  'taught',
#  'addict',
#  'bit',
#  'cut',
#  'novel',
#  'coming',
#  'truth',
#  'taking',
#  'turned',
#  'coffee',
#  'far',
#  'price',
#  "hasn't",
#  'television',
#  'meeting',
#  'sitting',
#  'war',
#  'company',
#  'since',
#  'japan',
#  'summer',
#  'afternoon',
#  'hello',
#  'sad',
#  'follow',
#  'smiled',
#  'turn',
#  'waited',
#  'warm',
#  'hurt',
#  'cry',
#  'serious',
#  'closed',
#  'weird',
#  'smiling',
#  'smoking',
#  'finished',
#  'questions',
#  'winter',
#  'sat',
#  'keys',
#  'song',
#  'caught',
#  'lunch',
#  'narrow',
#  'black',
#  "she's",
#  'animals',
#  'movie',
#  'seemed',
#  'born',
#  'light',
#  'flour',
#  'worried',
#  'acted',
#  'started',
#  'become',
#  'crazy',
#  'expect',
#  'letter',
#  'bread',
#  'interested',
#  'past',
#  'lose',
#  'choice',
#  'prison',
#  'weather',
#  'guitar',
#  'began',
#  'store',
#  'while',
#  'hat',
#  'sound',
#  'hospital',
#  'such',
#  'cost',
#  'floor',
#  'large',
#  'likes',
#  'until',
#  'view',
#  'lived',
#  'living',
#  'bottle',
#  'native',
#  'speaker',
#  'whether',
#  'minutes',
#  'words',
#  'usually',
#  'john',
#  'thanks',
#  'calm',
#  'fair',
#  'kiss',
#  'hurts',
#  'trust',
#  'thank',
#  'talked',
#  'carry',
#  'check',
#  'lying',
#  'curious',
#  'nervous',
#  'dance',
#  'romantic',
#  'dancing',
#  'green',
#  'honest',
#  'nonsense',
#  'touch',
#  'listening',
#  'scared',
#  'carefully',
#  'arrived',
#  'bag',
#  'safe',
#  'missed',
#  'sunday',
#  'manager',
#  'worked',
#  'women',
#  'waiting',
#  'extremely',
#  'game',
#  'clock',
#  'changed',
#  'coat',
#  'smoke',
#  'hungry',
#  'feeling',
#  'own',
#  'beach',
#  'fired',
#  'kid',
#  'rain',
#  'older',
#  'comes',
#  'speech',
#  'thinking',
#  'impossible',
#  'monkeys',
#  'climb',
#  'single',
#  'else',
#  'message',
#  '30',
#  'close',
#  'near',
#  'surprised',
#  'angry',
#  'happening',
#  'filled',
#  'marry',
#  'less',
#  'october',
#  'sometimes',
#  'somewhere',
#  'equals',
#  'early',
#  'responsibility',
#  'equal',
#  'homework',
#  'park',
#  'proud',
#  'painted',
#  'walking',
#  'earth',
#  'speaking',
#  'spent',
#  'actually',
#  'studied',
#  'bottom',
#  'trouble',
#  'because',
#  'hide',
#  'ran',
#  'goodbye',
#  'hit',
#  'perfect',
#  'wash',
#  'welcome',
#  'grab',
#  'cute',
#  'forgot',
#  'stand',
#  'dogs',
#  'above',
#  'along',
#  'quick',
#  'definitely',
#  'cheese',
#  'boys',
#  'cook',
#  'finish',
#  'straight',
#  'strange',
#  'tea',
#  'escaped',
#  'survived',
#  'quickly',
#  "it'll",
#  'hates',
#  'famous',
#  'passed',
#  'somebody',
#  'miss',
#  'head',
#  'bird',
#  'smart',
#  'dreams',
#  'radio',
#  'hand',
#  'disappeared',
#  'baby',
#  'drinks',
#  'attention',
#  'number',
#  'fight',
#  'camera',
#  'regret',
#  'spider',
#  'monkey',
#  'yes',
#  'kids',
#  'set',
#  'liar',
#  'even',
#  'headache',
#  'seven',
#  'laugh',
#  'outside',
#  'poor',
#  'easily',
#  'short',
#  'save',
#  'teachers',
#  'hour',
#  'pass',
#  'stopped',
#  'cake',
#  'another',
#  'butter',
#  'goes',
#  'sweet',
#  'guess',
#  'denied',
#  'bigger',
#  'stuck',
#  'useful',
#  'winning',
#  'library',
#  'train',
#  'writing',
#  'loved',
#  'sounds',
#  '2',
#  'needed',
#  'addictive',
#  'restaurant',
#  'abroad',
#  'attempted',
#  'tears',
#  'shirt',
#  'sooner',
#  'pizza',
#  'allowed',
#  'through',
#  'following',
#  'pictures',
#  'player',
#  'noise',
#  'intelligent',
#  'plays',
#  'reason',
#  'injured',
#  'months',
#  'waste',
#  'wife',
#  'front',
#  'delicious',
#  'teach',
#  'difficulty',
#  'prefer',
#  'umbrella',
#  'chess',
#  'men',
#  'exam',
#  'named',
#  'diagnosed',
#  'singer',
#  'means',
#  'several',
#  'repeat',
#  'wear',
#  'sentence',
#  'potatoes',
#  'saying',
#  'key',
#  'capital',
#  'concentrating',
#  'whole',
#  'success',
#  'death',
#  'united',
#  'each',
#  'alice',
#  'except',
#  'between',
#  'jump',
#  'begin',
#  'relax',
#  'join',
#  'wake',
#  'cool',
#  'ahead',
#  'deep',
#  'apologize',
#  'course',
#  'seriously',
#  'then',
#  'moved',
#  'slowly',
#  'face',
#  'exists',
#  "how's",
#  'chuckled',
#  'envy',
#  'accept',
#  'ignore',
#  'once',
#  'danced',
#  'helped',
#  'overslept',
#  'jail',
#  'moving',
#  'talks',
#  'plants',
#  'grow',
#  'drowned',
#  'giggled',
#  'ghosts',
#  'exist',
#  'horrible',
#  'liars',
#  'lawyer',
#  'fake',
#  'driving',
#  'refused',
#  'listened',
#  'succeeded',
#  'autistic',
#  'horses',
#  'volunteered',
#  'depressed',
#  'fighting',
#  'suit',
#  'peace',
#  'boring',
#  'autumn',
#  'korean',
#  'ice',
#  'melted',
#  'enjoy',
#  'voice',
#  'zoo',
#  'panic',
#  'empty',
#  'boss',
#  'pencil',
#  'secret',
#  'ours',
#  'sleeping',
#  'rabbits',
#  'aid',
#  'dead',
#  'thanked',
#  'proof',
#  'watermelon',
#  'glasses',
#  'sent',
#  'watched',
#  'shy',
#  'unhappy',
#  'mad',
#  "what're",
#  'lips',
#  'excuse',
#  'kept',
#  'chinese',
#  'shoes',
#  '2013',
#  'travel',
#  'whose',
#  'cup',
#  'tokyo',
#  'either',
#  'trees',
#  'funeral',
#  'committed',
#  'telling',
#  'paper',
#  'decision',
#  'recognized',
#  'ten',
#  'fix',
#  'common',
#  'joke',
#  'tree',
#  'africa',
#  'taxi',
#  'helping',
#  'unknown',
#  'teeth',
#  'heart',
#  'passport',
#  'window',
#  'lake',
#  'reply',
#  'suffer',
#  'cars',
#  'broke',
#  'building',
#  'opened',
#  'color',
#  'hire',
#  'picture',
#  'plus',
#  'sign',
#  'entered',
#  'forest',
#  'skills',
#  'catch',
#  'cell',
#  'drunk',
#  'weight',
#  'magazine',
#  'spring',
#  'discount',
#  'mountain',
#  'sold',
#  'eaten',
#  'address',
#  'weekend',
#  'road',
#  'completely',
#  '1',
#  'scissors',
#  'till',
#  'street',
#  'sense',
#  'future',
#  'finally',
#  'ashamed',
#  'body',
#  'humans',
#  'mouth',
#  'law',
#  'their',
#  'test',
#  "he'll",
#  'glad',
#  'dress',
#  'noticed',
#  'supposed',
#  ...]

# %%
import pandas as pd

pd.DataFrame(en_embedding_matrix, index=eng_word_index)
# Out:
#                   0         1        2         3         4         5   \
# <pad>       0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# <oov>       0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# i          -0.046539  0.619660  0.56647 -0.465840 -1.189000  0.445990
# tom        -0.583880 -0.469400  0.16855 -1.670300 -0.116010  0.048738
# to         -0.189700  0.050024  0.19084 -0.049184 -0.089737  0.210060
# ...              ...       ...      ...       ...       ...       ...
# whom        0.341680  0.545720 -0.15683 -0.205450 -0.199470  0.389270
# intimately  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# millions    0.622040  1.063600  0.13146 -0.203880  0.555570  0.443570
# inhabit     0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# created     0.056525 -0.181480 -0.20936 -0.070561  0.950130  0.176020
#
#                   6         7         8        9   ...        90        91  \
# <pad>       0.000000  0.000000  0.000000  0.00000  ...  0.000000  0.000000
# <oov>       0.000000  0.000000  0.000000  0.00000  ...  0.000000  0.000000
# i           0.066035  0.319100  0.146790 -0.22119  ... -0.323430 -0.431210
# tom        -0.342010 -0.376910 -0.953080 -0.88260  ...  0.264290  0.337860
# to         -0.549520  0.098377 -0.201350  0.34241  ... -0.131340  0.058617
# ...              ...       ...       ...      ...  ...       ...       ...
# whom       -0.017266 -0.244750  0.124760 -0.34392  ...  0.142210 -0.556420
# intimately  0.000000  0.000000  0.000000  0.00000  ...  0.000000  0.000000
# millions   -0.524210  0.040587  0.470640 -0.53788  ... -0.063191 -0.111260
# inhabit     0.000000  0.000000  0.000000  0.00000  ...  0.000000  0.000000
# created    -0.070017 -0.159640  0.047953 -0.38843  ...  0.090936 -0.250330
#
#                  92        93        94        95        96        97  \
# <pad>       0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# <oov>       0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# i           0.41392  0.283740 -0.709310  0.150030 -0.215400 -0.376160
# tom         0.35791  0.549010  0.006725  0.281580  0.343730  0.137040
# to         -0.31869 -0.614190 -0.623930 -0.415480 -0.038175 -0.398040
# ...             ...       ...       ...       ...       ...       ...
# whom        0.45764 -0.243960 -1.146800  0.330140 -0.900430 -0.014213
# intimately  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# millions    0.66609 -0.972050 -0.558910 -0.837910 -0.147160  0.862920
# inhabit     0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# created    -0.32441 -0.012409  0.268150  0.063334 -0.152150 -0.627600
#
#                   98       99
# <pad>       0.000000  0.00000
# <oov>       0.000000  0.00000
# i          -0.032502  0.80620
# tom         0.089572 -0.54277
# to          0.476470 -0.15983
# ...              ...      ...
# whom        0.161420 -0.44483
# intimately  0.000000  0.00000
# millions    0.302910 -0.22564
# inhabit     0.000000  0.00000
# created     0.229480 -0.44526
#
# [3201 rows x 100 columns]

# %% [markdown]
# ##### 인코더 모델

# %%
from tensorflow.keras import layers, models

LATENT_DIM = 512

encoder_inputs = layers.Input(shape=(eng_max_len, ))
en_embedding_layer = layers.Embedding(eng_num_words + 1, EMBEDDING_DIM,
                                      weights=[en_embedding_matrix])
x = en_embedding_layer(encoder_inputs)
encoder_outputs, h, c = layers.LSTM(LATENT_DIM, return_state=True)(x)
encoder_states = [h, c]

encoder_model = models.Model(inputs=encoder_inputs, outputs=encoder_states)
encoder_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 101)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, 101, 100)       │       320,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ [(None, 512), (None,   │     1,255,424 │
# │                                 │ 512), (None, 512)]     │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,575,524 (6.01 MB)
#  Trainable params: 1,575,524 (6.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##### 디코더 모델

# %%
decoder_inputs = layers.Input(shape=(kor_max_len, ))
ko_embedding_layer = layers.Embedding(kor_num_words + 1, EMBEDDING_DIM)
x = ko_embedding_layer(decoder_inputs)

decoder_lstm = layers.LSTM(LATENT_DIM, return_sequences=True, return_state=True)
x, h, c = decoder_lstm(x, initial_state=encoder_states)

decoder_dense = layers.Dense(kor_num_words + 1, activation='softmax')
decoder_outputs = decoder_dense(x)

decoder_teacher_forcing_model = models.Model(
    inputs=[encoder_inputs, decoder_inputs],
    outputs=decoder_outputs
)

decoder_teacher_forcing_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 101)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 90)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 101, 100)  │    320,100 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 90, 100)   │    828,900 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 512),     │  1,255,424 │ embedding[0][0]   │
# │                     │ (None, 512),      │            │                   │
# │                     │ (None, 512)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 90, 512), │  1,255,424 │ embedding_1[0][0… │
# │                     │ (None, 512),      │            │ lstm[0][1],       │
# │                     │ (None, 512)]      │            │ lstm[0][2]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 90, 8289)  │  4,252,257 │ lstm_1[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,912,105 (30.18 MB)
#  Trainable params: 7,912,105 (30.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 모델 시각화 목적 패키지 install
# !pip install pydot pydotplus graphviz
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (3.0.4)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (0.21)
# Requirement already satisfied: pyparsing>=3.0.9 in /usr/local/lib/python3.12/dist-packages (from pydot) (3.2.5)

# %%
from tensorflow.keras.utils import plot_model

plot_model(decoder_teacher_forcing_model, show_shapes=True)

# %% [markdown]
# ##### 모델 학습

# %%
decoder_teacher_forcing_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = decoder_teacher_forcing_model.fit(
    [eng_inputs_padded, kor_inputs_padded],
    kor_targets_padded,
    batch_size=64,
    epochs=70,
    validation_split=0.2
)
# Out:
# Epoch 1/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.8874 - loss: 2.6210 - val_accuracy: 0.9239 - val_loss: 0.6777
# Epoch 2/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - accuracy: 0.9607 - loss: 0.3284 - val_accuracy: 0.9302 - val_loss: 0.6364
# Epoch 3/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - accuracy: 0.9610 - loss: 0.3134 - val_accuracy: 0.9309 - val_loss: 0.6285
# Epoch 4/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 174ms/step - accuracy: 0.9611 - loss: 0.3031 - val_accuracy: 0.9310 - val_loss: 0.6327
# Epoch 5/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 176ms/step - accuracy: 0.9609 - loss: 0.2968 - val_accuracy: 0.9311 - val_loss: 0.6421
# Epoch 6/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 177ms/step - accuracy: 0.9607 - loss: 0.2901 - val_accuracy: 0.9313 - val_loss: 0.6423
# Epoch 7/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 21s 179ms/step - accuracy: 0.9613 - loss: 0.2804 - val_accuracy: 0.9318 - val_loss: 0.6447
# Epoch 8/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 183ms/step - accuracy: 0.9619 - loss: 0.2683 - val_accuracy: 0.9320 - val_loss: 0.6577
# Epoch 9/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9624 - loss: 0.2556 - val_accuracy: 0.9324 - val_loss: 0.6541
# Epoch 10/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.9629 - loss: 0.2451 - val_accuracy: 0.9327 - val_loss: 0.6592
# Epoch 11/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 178ms/step - accuracy: 0.9637 - loss: 0.2328 - val_accuracy: 0.9329 - val_loss: 0.6680
# Epoch 12/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 178ms/step - accuracy: 0.9641 - loss: 0.2202 - val_accuracy: 0.9332 - val_loss: 0.6624
# Epoch 13/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9651 - loss: 0.2063 - val_accuracy: 0.9335 - val_loss: 0.6685
# Epoch 14/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9656 - loss: 0.1940 - val_accuracy: 0.9337 - val_loss: 0.6729
# Epoch 15/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9669 - loss: 0.1780 - val_accuracy: 0.9338 - val_loss: 0.6840
# Epoch 16/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 179ms/step - accuracy: 0.9684 - loss: 0.1636 - val_accuracy: 0.9340 - val_loss: 0.6870
# Epoch 17/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.9705 - loss: 0.1470 - val_accuracy: 0.9341 - val_loss: 0.6915
# Epoch 18/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.9733 - loss: 0.1337 - val_accuracy: 0.9344 - val_loss: 0.7040
# Epoch 19/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9766 - loss: 0.1188 - val_accuracy: 0.9344 - val_loss: 0.7093
# Epoch 20/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9801 - loss: 0.1029 - val_accuracy: 0.9346 - val_loss: 0.7140
# Epoch 21/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9824 - loss: 0.0927 - val_accuracy: 0.9344 - val_loss: 0.7221
# Epoch 22/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9846 - loss: 0.0808 - val_accuracy: 0.9348 - val_loss: 0.7310
# Epoch 23/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9869 - loss: 0.0688 - val_accuracy: 0.9347 - val_loss: 0.7342
# Epoch 24/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9882 - loss: 0.0621 - val_accuracy: 0.9349 - val_loss: 0.7461
# Epoch 25/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9896 - loss: 0.0544 - val_accuracy: 0.9349 - val_loss: 0.7488
# Epoch 26/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9906 - loss: 0.0481 - val_accuracy: 0.9347 - val_loss: 0.7569
# Epoch 27/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9918 - loss: 0.0427 - val_accuracy: 0.9348 - val_loss: 0.7616
# Epoch 28/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9925 - loss: 0.0381 - val_accuracy: 0.9351 - val_loss: 0.7668
# Epoch 29/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9934 - loss: 0.0340 - val_accuracy: 0.9347 - val_loss: 0.7696
# Epoch 30/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9941 - loss: 0.0307 - val_accuracy: 0.9346 - val_loss: 0.7745
# Epoch 31/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9944 - loss: 0.0283 - val_accuracy: 0.9347 - val_loss: 0.7813
# Epoch 32/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.9952 - loss: 0.0249 - val_accuracy: 0.9347 - val_loss: 0.7842
# Epoch 33/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.9955 - loss: 0.0232 - val_accuracy: 0.9347 - val_loss: 0.7972
# Epoch 34/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.9960 - loss: 0.0206 - val_accuracy: 0.9350 - val_loss: 0.7939
# Epoch 35/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9962 - loss: 0.0190 - val_accuracy: 0.9348 - val_loss: 0.7981
# Epoch 36/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9965 - loss: 0.0172 - val_accuracy: 0.9349 - val_loss: 0.8034
# Epoch 37/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.9966 - loss: 0.0163 - val_accuracy: 0.9348 - val_loss: 0.8093
# Epoch 38/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.9970 - loss: 0.0147 - val_accuracy: 0.9351 - val_loss: 0.8138
# Epoch 39/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9972 - loss: 0.0137 - val_accuracy: 0.9349 - val_loss: 0.8108
# Epoch 40/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9973 - loss: 0.0127 - val_accuracy: 0.9350 - val_loss: 0.8145
# Epoch 41/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9975 - loss: 0.0120 - val_accuracy: 0.9348 - val_loss: 0.8257
# Epoch 42/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9976 - loss: 0.0112 - val_accuracy: 0.9351 - val_loss: 0.8230
# Epoch 43/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9978 - loss: 0.0103 - val_accuracy: 0.9351 - val_loss: 0.8253
# Epoch 44/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.9978 - loss: 0.0098 - val_accuracy: 0.9349 - val_loss: 0.8274
# Epoch 45/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9980 - loss: 0.0092 - val_accuracy: 0.9352 - val_loss: 0.8340
# Epoch 46/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.9980 - loss: 0.0088 - val_accuracy: 0.9349 - val_loss: 0.8363
# Epoch 47/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9980 - loss: 0.0082 - val_accuracy: 0.9349 - val_loss: 0.8418
# Epoch 48/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 179ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.9351 - val_loss: 0.8442
# Epoch 49/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9981 - loss: 0.0076 - val_accuracy: 0.9351 - val_loss: 0.8495
# Epoch 50/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9983 - loss: 0.0068 - val_accuracy: 0.9347 - val_loss: 0.8490
# Epoch 51/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9982 - loss: 0.0068 - val_accuracy: 0.9350 - val_loss: 0.8558
# Epoch 52/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9982 - loss: 0.0066 - val_accuracy: 0.9351 - val_loss: 0.8547
# Epoch 53/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9983 - loss: 0.0062 - val_accuracy: 0.9350 - val_loss: 0.8591
# Epoch 54/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9350 - val_loss: 0.8583
# Epoch 55/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9981 - loss: 0.0060 - val_accuracy: 0.9351 - val_loss: 0.8597
# Epoch 56/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9982 - loss: 0.0057 - val_accuracy: 0.9351 - val_loss: 0.8632
# Epoch 57/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9349 - val_loss: 0.8661
# Epoch 58/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9351 - val_loss: 0.8683
# Epoch 59/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9983 - loss: 0.0052 - val_accuracy: 0.9350 - val_loss: 0.8696
# Epoch 60/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.9351 - val_loss: 0.8728
# Epoch 61/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - accuracy: 0.9983 - loss: 0.0051 - val_accuracy: 0.9350 - val_loss: 0.8808
# Epoch 62/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.9982 - loss: 0.0050 - val_accuracy: 0.9351 - val_loss: 0.8751
# Epoch 63/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 19s 179ms/step - accuracy: 0.9984 - loss: 0.0047 - val_accuracy: 0.9353 - val_loss: 0.8836
# Epoch 64/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 184ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9350 - val_loss: 0.8826
# Epoch 65/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9351 - val_loss: 0.8837
# Epoch 66/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9350 - val_loss: 0.8814
# Epoch 67/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9983 - loss: 0.0045 - val_accuracy: 0.9350 - val_loss: 0.8856
# Epoch 68/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9983 - loss: 0.0045 - val_accuracy: 0.9351 - val_loss: 0.8895
# Epoch 69/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9983 - loss: 0.0043 - val_accuracy: 0.9352 - val_loss: 0.8880
# Epoch 70/70
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 179ms/step - accuracy: 0.9984 - loss: 0.0041 - val_accuracy: 0.9350 - val_loss: 0.8915

# %%
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot()
plt.show()

# %%
# 모델 저장
decoder_teacher_forcing_model.save('decoder_teacher_forcing_model.keras')

# %%
# 모델 로드
from tensorflow.keras.models import load_model
decoder_teacher_forcing_model = load_model('decoder_teacher_forcing_model.keras')

# %% [markdown]
# ### 디코더 추론 모델

# %% [markdown]
# ##### 추론 함수

# %%
# 입력 states (이전 timestep의 hidden_state, cell_state)
decoder_hidden_state = layers.Input(shape=(LATENT_DIM,))
decoder_cell_state = layers.Input(shape=(LATENT_DIM,))
decoder_states_inputs = [decoder_hidden_state, decoder_cell_state]

# 토큰 입력 (이전 timestep의 output)
decoder_single_input = layers.Input(shape=(1,))

# 학습된 임베딩
x = ko_embedding_layer(decoder_single_input)

# 학습된 LSTM
x, h, c = decoder_lstm(x, initial_state=decoder_states_inputs)
decoder_states = [h, c]

# 학습된 dense
decoder_outputs_ = decoder_dense(x)

decoder_inference_model = models.Model(
    inputs=[decoder_single_input] + decoder_states_inputs,
    outputs=[decoder_outputs_] + decoder_states
)
decoder_inference_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 1, 100)    │    828,900 │ input_layer_4[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 512)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 512)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 1, 512),  │  1,255,424 │ embedding_1[1][0… │
# │                     │ (None, 512),      │            │ input_layer_2[0]… │
# │                     │ (None, 512)]      │            │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 8289)   │  4,252,257 │ lstm_1[1][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,336,581 (24.17 MB)
#  Trainable params: 6,336,581 (24.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(decoder_inference_model, show_shapes=True)

# %% [markdown]
# ##### 추론 함수

# %%
def translate(input_seq):
    # 인코더
    # input_seq 통과(추론) -> hidden_state, cell_state만 반환
    encoder_states_value = encoder_model.predict(input_seq)
    decoder_states_value = encoder_states_value    # 초기값

    # 디코더
    # 1. <sos><eos>
    sos_index = kor_tokenizer.word_index['<sos>']
    eos_index = kor_tokenizer.word_index['<eos>']

    # 2. target_seq 준비 (디코더 출력)
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = sos_index

    # 3. 순차적으로 디코딩(= 번역)
    output_sentence = []

    for _ in range(kor_max_len):
        output_tokens, h, c = \
            decoder_inference_model.predict([target_seq] + decoder_states_value)

        pred_proba = output_tokens[0, 0, :]
        pred_index = np.argmax(pred_proba)

        if pred_index == eos_index:
            break

        if pred_index > 0:
            word = kor_tokenizer.index_word[pred_index]
            output_sentence.append(word)

        target_seq[0, 0] = pred_index
        decoder_states_value = [h, c]

    return " ".join(output_sentence)

# %%
print(eng_inputs[:1])

input_seq = eng_inputs_padded[:1]
output_sent = translate(input_seq)

print(output_sent)
# Out:
# ['Go.']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 가.

# %%
for _ in range(5):
    idx = np.random.choice(len(eng_inputs_padded))
    input_seq = eng_inputs_padded[idx:idx+1]
    output_sent = translate(input_seq)
    display("입력 영문:", eng_inputs[idx])
    display("학습한 국문:", kor_inputs[idx])
    display("추론한 국문:", output_sent)
    display()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# '입력 영문:'
# "That would be like sawing off the branch you're sitting on."
# '학습한 국문:'
# '<sos> 그건 니가 앉아있는 가지를 쳐내는 꼴이야.'
# '추론한 국문:'
# '그 가게는 일주일 문을 알려 지도 있다.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# '입력 영문:'
# "It's good."
# '학습한 국문:'
# '<sos> 괜찮네요.'
# '추론한 국문:'
# '좋아요.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# '입력 영문:'
# 'It snowed a lot last year.'
# '학습한 국문:'
# '<sos> 작년에 눈이 엄청 내렸어.'
# '추론한 국문:'
# '작년에 눈이 엄청 내렸어.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# '입력 영문:'
# 'Do you know what this means?'
# '학습한 국문:'
# '<sos> 이것이 무슨 뜻인지 알겠어요?'
# '추론한 국문:'
# '이것이 무슨 뜻인지 알겠어요?'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# '입력 영문:'
# "I'll take it."
# '학습한 국문:'
# '<sos> 내가 가져갈게.'
# '추론한 국문:'
# '내가 가져갈게.'

# %%
def translate_eng2kor(eng_text):
    # 입력 데이터 전처리
    input_seq = eng_tokenizer.texts_to_sequences(eng_text)
    input_seq = pad_sequences(input_seq, maxlen=eng_max_len)
    return translate(input_seq)    # 추론 함수 호출

eng_texts = [
    "My lips are red.",
    "French is interesting.",
    "I like bus",
    "Let\'s study",
    "I ate sandwich"
]

for eng_text in eng_texts:
    kor_text = translate_eng2kor([eng_text])
    display(eng_text, kor_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 'My lips are red.'
# '내 가방은 비어 있다.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 'French is interesting.'
# '프랑스어는 흥미로워.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 'I like bus'
# '나는 일하는 것이 좋다.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# "Let's study"
# '당신은 읽어.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 'I ate sandwich'
# '나는 초콜렛을 싫어한다.'
